# %% [markdown]
# # 调包与数据加载

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
import matplotlib.pyplot as plt
from pytorch_msssim import ms_ssim

# mps
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(device)
# Out:
# mps

# %%
import numpy as np
import torch.nn.functional as F
import torch

# === 1. 加载原始 HR 数据 ===
hr_train = np.load("tm/HR_data_train_tm.npy")[:200]
hr_valid = np.load("tm/HR_data_valid_tm.npy")[:200]
hr_test = np.load("tm/HR_data_test_tm.npy")[:200]

# === 2. 生成 LR 数据（双线性插值至 16×16） ===
def downsample(hr_array, scale=4):
    tensor = torch.tensor(hr_array, dtype=torch.float32)
    return F.interpolate(tensor, scale_factor=1/scale, mode="bilinear", align_corners=False).numpy()

lr_train = downsample(hr_train)
lr_valid = downsample(hr_valid)
lr_test = downsample(hr_test)

# === 3. 保存为 .npy 文件 ===
np.save("tm/HR_data_train_40.npy", hr_train)
np.save("tm/LR_data_train_40.npy", lr_train)
np.save("tm/HR_data_valid_40.npy", hr_valid)
np.save("tm/LR_data_valid_40.npy", lr_valid)
np.save("tm/HR_data_test_40.npy", hr_test)
np.save("tm/LR_data_test_40.npy", lr_test)

# === 4. 计算并保存 mean/std（仅用 HR_train）===
mean = np.mean(hr_train, axis=(0, 2, 3))[:, None, None]
std = np.std(hr_train, axis=(0, 2, 3))[:, None, None]
np.save("tm/mean_40.npy", mean)
np.save("tm/std_40.npy", std)

print("✅ 完成：生成 LR/HR 切片、保存归一化参数，包括 test")
print(lr_train.shape)
# Out:
# ✅ 完成：生成 LR/HR 切片、保存归一化参数，包括 test
# (200, 2, 16, 16)

# %%
class WeatherDataset(Dataset):
    def __init__(self, lr_path, hr_path, mean_path, std_path):
        self.lr = np.load(lr_path)
        self.hr = np.load(hr_path)
        self.mean = np.load(mean_path).reshape(2, 1, 1)
        self.std = np.load(std_path).reshape(2, 1, 1)

    def __len__(self):
        return len(self.lr)

    def __getitem__(self, idx):
        lr = (self.lr[idx] - self.mean) / self.std
        hr = (self.hr[idx] - self.mean) / self.std
        return torch.tensor(lr, dtype=torch.float32), torch.tensor(hr, dtype=torch.float32)

# %% [markdown]
# # Generator 模块

# %%
class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Conv2d(channel, channel // reduction, 1, bias=False)
        self.relu = nn.ReLU(inplace=True)
        self.fc2 = nn.Conv2d(channel // reduction, channel, 1, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # Squeeze: Global Average Pooling
        y = self.avg_pool(x)
        # Excitation: Fully connected layers
        y = self.fc1(y)
        y = self.relu(y)
        y = self.fc2(y)
        y = self.sigmoid(y)
        return x * y

class MultiScaleFeatureFusion(nn.Module):
    def __init__(self, in_channels, features):
        super(MultiScaleFeatureFusion, self).__init__()
        self.scale1 = nn.Conv2d(in_channels, features, kernel_size=3, padding=1)
        self.scale2 = nn.Conv2d(in_channels, features, kernel_size=5, padding=2)
        self.scale3 = nn.Conv2d(in_channels, features, kernel_size=7, padding=3)
        
        self.fusion = nn.Conv2d(features * 3, features, kernel_size=1)

    def forward(self, x):
        x1 = self.scale1(x)
        x2 = self.scale2(x)
        x3 = self.scale3(x)
        fused = torch.cat([x1, x2, x3], dim=1)
        return self.fusion(fused)

class SRResNetGenerator(nn.Module):
    def __init__(self, in_channels=2, out_channels=2, features=64):
        super(SRResNetGenerator, self).__init__()
        self.initial = nn.Sequential(
            nn.Conv2d(in_channels, features, kernel_size=9, padding=4),
            nn.PReLU()
        )

        # Multi-scale feature fusion
        self.multi_scale_fusion = MultiScaleFeatureFusion(in_channels=features, features=features)

        # 8 Residual Blocks with SE
        res_blocks = []
        for _ in range(8):
            res_blocks.append(nn.Sequential(
                nn.Conv2d(features, features, kernel_size=3, padding=1),
                nn.BatchNorm2d(features),
                nn.PReLU(),
                nn.Conv2d(features, features, kernel_size=3, padding=1),
                nn.BatchNorm2d(features),
                SEBlock(features)  # Add SE Block after each residual block
            ))
        self.res_blocks = nn.Sequential(*res_blocks)

        self.mid_conv = nn.Sequential(
            nn.Conv2d(features, features, kernel_size=3, padding=1),
            nn.BatchNorm2d(features)
        )

        self.upsample = nn.Sequential(
            nn.Conv2d(features, features * 4, 3, 1, 1),
            nn.PixelShuffle(2),
            nn.PReLU(),
            nn.Conv2d(features, features * 4, 3, 1, 1),
            nn.PixelShuffle(2),
            nn.PReLU(),
        )

        self.final = nn.Sequential(
            nn.Conv2d(features, out_channels, kernel_size=9, padding=4),
            nn.Tanh()
        )

    def forward(self, x):
        x1 = self.initial(x)

        # Multi-scale feature fusion
        x2 = self.multi_scale_fusion(x1)
        
        # Combine initial features with multi-scale features
        res = x1 + x2
        for block in self.res_blocks:
            res = res + block(res)

        out = self.mid_conv(res)
        out = out + x1
        out = self.upsample(out)
        return self.final(out)

# %% [markdown]
# # discriminator模块

# %%
import torch.nn as nn

class Discriminator(nn.Module):
    def __init__(self, in_channels=4, features=64):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv2d(in_channels, features, 4, 2, 1),  # (B, 64, 32, 32)
            nn.LeakyReLU(0.2),
            nn.Conv2d(features, features * 2, 4, 2, 1),  # (B, 128, 16, 16)
            nn.BatchNorm2d(features * 2),
            nn.LeakyReLU(0.2),
            nn.Conv2d(features * 2, features * 4, 4, 2, 1),  # (B, 256, 8, 8)
            nn.BatchNorm2d(features * 4),
            nn.LeakyReLU(0.2),
            nn.Conv2d(features * 4, 1, 4, 1, 1),  # (B, 1, 7, 7) => PatchGAN 输出
            nn.Sigmoid()
        )

    def forward(self, lr_up, hr_or_fake):
        # Ensure both inputs are [B, 2, 64, 64]
        if lr_up.shape[-2:] != hr_or_fake.shape[-2:]:
            raise ValueError(f"Shape mismatch: lr_up={lr_up.shape}, hr={hr_or_fake.shape}")
        x = torch.cat([lr_up, hr_or_fake], dim=1)  # => [B, 4, H, W]
        return self.model(x)

# %% [markdown]
# # 评估指标计算

# %%
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
import torch.nn.functional as F

def compute_psnr_ssim(pred, target):
    # shape(N, H, W, C)
    pred = pred.detach().cpu().numpy().transpose(0, 2, 3, 1)
    target = target.detach().cpu().numpy().transpose(0, 2, 3, 1)
    data_range = max(target.max(), pred.max()) - min(target.min(), pred.min())

    psnr_total, ssim_total = 0, 0
    for p, t in zip(pred, target):
        psnr_total += peak_signal_noise_ratio(t, p, data_range=data_range)
        ssim_total += structural_similarity(t, p, channel_axis=-1, data_range=data_range)
    return psnr_total / len(pred), ssim_total / len(pred)

def compute_rmse(pred, target):
    return torch.sqrt(torch.mean((pred - target) ** 2))

def compute_mae(pred, target):
    return torch.mean(torch.abs(pred - target))


# === 添加 SSIM Loss ===
def ssim_loss(pred, target, C1=0.01**2, C2=0.03**2):
    mu_x = F.avg_pool2d(pred, 3, 1, 1)
    mu_y = F.avg_pool2d(target, 3, 1, 1)
    sigma_x = F.avg_pool2d(pred ** 2, 3, 1, 1) - mu_x ** 2
    sigma_y = F.avg_pool2d(target ** 2, 3, 1, 1) - mu_y ** 2
    sigma_xy = F.avg_pool2d(pred * target, 3, 1, 1) - mu_x * mu_y
    ssim_n = (2 * mu_x * mu_y + C1) * (2 * sigma_xy + C2)
    ssim_d = (mu_x ** 2 + mu_y ** 2 + C1) * (sigma_x + sigma_y + C2)
    ssim_map = ssim_n / (ssim_d + 1e-8)
    return 1 - ssim_map.mean()

# 加载 min/max（你刚才保存过）
hr_min = np.load("tm/min_40.npy")[:, None, None]
hr_max = np.load("tm/max_40.npy")[:, None, None]

def minmax_scale(tensor):
    # 缩放到 0~1
    return (tensor - torch.tensor(hr_min, dtype=torch.float32).to(tensor.device)) / \
           (torch.tensor(hr_max - hr_min, dtype=torch.float32).to(tensor.device))

# %%
def evaluate_on_loader(model, loader, device):
    model.eval()
    preds, targets = [], []
    with torch.no_grad():
        for lr, hr in loader:
            lr, hr = lr.to(device), hr.to(device)
            pred = model(lr)
            pred = F.interpolate(pred, size=hr.shape[-2:], mode="bilinear", align_corners=False)
            preds.append(pred.cpu())
            targets.append(hr.cpu())
    preds = torch.cat(preds, dim=0)
    targets = torch.cat(targets, dim=0)
    return compute_psnr_ssim(preds, targets)

# %%
train_set = WeatherDataset(
    "tm/LR_data_train_40.npy", "tm/HR_data_train_40.npy",
    "tm/mean_40.npy", "tm/std_40.npy"
)
val_set = WeatherDataset(
    "tm/LR_data_valid_40.npy", "tm/HR_data_valid_40.npy",
    "tm/mean_40.npy", "tm/std_40.npy"
)
test_set = WeatherDataset(
    "tm/LR_data_test_40.npy", "tm/HR_data_test_40.npy",
    "tm/mean_40.npy", "tm/std_40.npy"
)

test_loader = DataLoader(test_set, batch_size=8, shuffle=False)
train_loader = DataLoader(train_set, batch_size=8, shuffle=True)
val_loader = DataLoader(val_set, batch_size=8, shuffle=False)

# %%
# === Gradient Difference Loss (GDL) ===
def gradient_difference_loss(fake, hr):
    grad_fake_x = torch.abs(fake[:, :, 1:, :] - fake[:, :, :-1, :])
    grad_fake_y = torch.abs(fake[:, :, :, 1:] - fake[:, :, :, :-1])
    
    grad_hr_x = torch.abs(hr[:, :, 1:, :] - hr[:, :, :-1, :])
    grad_hr_y = torch.abs(hr[:, :, :, 1:] - hr[:, :, :, :-1])
    
    loss_x = F.l1_loss(grad_fake_x, grad_hr_x)
    loss_y = F.l1_loss(grad_fake_y, grad_hr_y)
    
    return loss_x + loss_y

# === Charbonnier Loss ===
class CharbonnierLoss(torch.nn.Module):
    """Charbonnier Loss (L1-like but differentiable at zero)"""
    def __init__(self, epsilon=1e-3):
        super(CharbonnierLoss, self).__init__()
        self.epsilon = epsilon

    def forward(self, prediction, target):
        diff = prediction - target
        loss = torch.mean(torch.sqrt(diff ** 2 + self.epsilon ** 2))
        return loss

# 初始化 Charbonnier 损失
charbonnier_loss = CharbonnierLoss()

# %% [markdown]
# # 训练

# %%
# === 6. Model Initialization ===
G = SRResNetGenerator().to(device)
D = Discriminator().to(device)
criterion_GAN = nn.BCEWithLogitsLoss()
criterion_L1 = nn.L1Loss()
opt_G = torch.optim.Adam(G.parameters(), lr=1e-3, betas=(0.5, 0.999), weight_decay=1e-4)
opt_D = torch.optim.Adam(D.parameters(), lr=1e-3, betas=(0.5, 0.999), weight_decay=1e-4)
with torch.no_grad():
    dummy_input = torch.randn(1, 2, 16, 16).to(device)
    dummy_output = G(dummy_input)
    print(f"✅ G output shape: {dummy_output.shape}")  # 应该是 [1, 2, 64, 64]
# Out:
# ✅ G output shape: torch.Size([1, 2, 64, 64])

# %%
# 初始化 Charbonnier 损失
charbonnier_loss = CharbonnierLoss()

# === Training Loop ===
num_epochs = 200
train_psnrs, train_ssims, train_rmses, train_maes = [], [], [], []
val_psnrs, val_ssims, val_rmses, val_maes = [], [], [], []

for epoch in range(num_epochs):
    G.train()
    for lr, hr in train_loader:
        lr, hr = lr.to(device), hr.to(device)

        # === Forward Generator ===
        fake = G(lr).to(device)
        lr_up = F.interpolate(lr, size=hr.shape[-2:], mode="bilinear", align_corners=False)

        # === Train Discriminator ===
        D_real = D(lr_up, hr).to(device)
        D_fake = D(lr_up, fake.detach()).to(device)
        loss_D = (
            criterion_GAN(D_real, torch.ones_like(D_real)) +
            criterion_GAN(D_fake, torch.zeros_like(D_fake))
        ) * 0.5
        opt_D.zero_grad()
        loss_D.backward()
        opt_D.step()

        # === Train Generator ===
        pred = D(lr_up, fake)

        # === Compute All Losses ===
        loss_ssim = ssim_loss(fake, hr)                     # SSIM Loss
        loss_gdl = gradient_difference_loss(fake, hr)       # GDL Loss
        loss_charbonnier = charbonnier_loss(fake, hr)       # Charbonnier Loss
        loss_gan = criterion_GAN(pred, torch.ones_like(pred))  # GAN Loss

        # === Final Generator Loss (Weighted Sum) ===
        loss_G = (
            0.01 * loss_gan +             # GAN Loss (对抗学习)
            1.0 * loss_ssim +             # SSIM (结构相似)
            0.5 * loss_gdl +              # GDL (梯度差异)
            1.0 * loss_charbonnier        # Charbonnier (平滑差异)
        )

        # === Backpropagation ===
        opt_G.zero_grad()
        loss_G.backward()
        opt_G.step()

    # === Evaluation Phase ===
    train_pred = G(lr)
    train_pred = F.interpolate(train_pred, size=hr.shape[-2:], mode="bilinear", align_corners=False).to(device)
    # 评估
    train_pred_mm = minmax_scale(train_pred)
    hr_mm = minmax_scale(hr)
    psnr_train, ssim_train = compute_psnr_ssim(train_pred, hr)
    rmse_train = compute_rmse(train_pred_mm, hr_mm)
    mae_train = compute_mae(train_pred_mm, hr_mm)

    train_psnrs.append(psnr_train)
    train_ssims.append(ssim_train)
    train_rmses.append(rmse_train)
    train_maes.append(mae_train)

    # === Validation Phase ===
    G.eval()
    with torch.no_grad():
        val_lr, val_hr = next(iter(val_loader))
        val_lr, val_hr = val_lr.to(device), val_hr.to(device)
        pred_hr = G(val_lr)
        pred_hr = F.interpolate(pred_hr, size=val_hr.shape[-2:], mode="bilinear", align_corners=False).to(device)

        pred_val_mm = minmax_scale(pred_hr)
        val_hr_mm = minmax_scale(val_hr)
        psnr_val, ssim_val = compute_psnr_ssim(pred_hr, val_hr)
        rmse_val = compute_rmse(pred_val_mm, val_hr_mm)
        mae_val = compute_mae(pred_val_mm, val_hr_mm)

        val_psnrs.append(psnr_val)
        val_ssims.append(ssim_val)
        val_rmses.append(rmse_val)
        val_maes.append(mae_val)

    # === Print summary ===
    print(f"Epoch {epoch+1}: "
          f"Train PSNR={psnr_train:.2f}, SSIM={ssim_train:.4f}, RMSE={rmse_train:.4f}, MAE={mae_train:.4f} | "
          f"Valid PSNR={psnr_val:.2f}, SSIM={ssim_val:.4f}, RMSE={rmse_val:.4f}, MAE={mae_val:.4f}")
# Out:
# Epoch 1: Train PSNR=22.22, SSIM=0.4361, RMSE=0.0072, MAE=0.0040 | Valid PSNR=20.76, SSIM=0.4772, RMSE=0.0114, MAE=0.0059
# Epoch 2: Train PSNR=23.12, SSIM=0.4959, RMSE=0.0062, MAE=0.0036 | Valid PSNR=21.32, SSIM=0.5487, RMSE=0.0114, MAE=0.0058
# Epoch 3: Train PSNR=23.57, SSIM=0.5802, RMSE=0.0065, MAE=0.0035 | Valid PSNR=21.17, SSIM=0.5751, RMSE=0.0113, MAE=0.0057
# Epoch 4: Train PSNR=24.33, SSIM=0.6523, RMSE=0.0053, MAE=0.0028 | Valid PSNR=21.38, SSIM=0.6259, RMSE=0.0115, MAE=0.0059
# Epoch 5: Train PSNR=23.88, SSIM=0.7101, RMSE=0.0072, MAE=0.0037 | Valid PSNR=21.36, SSIM=0.6994, RMSE=0.0118, MAE=0.0059
# Epoch 6: Train PSNR=25.07, SSIM=0.7120, RMSE=0.0052, MAE=0.0026 | Valid PSNR=21.96, SSIM=0.6943, RMSE=0.0111, MAE=0.0053
# Epoch 7: Train PSNR=25.61, SSIM=0.7280, RMSE=0.0054, MAE=0.0028 | Valid PSNR=22.08, SSIM=0.7085, RMSE=0.0110, MAE=0.0053
# Epoch 8: Train PSNR=25.74, SSIM=0.7701, RMSE=0.0064, MAE=0.0030 | Valid PSNR=22.15, SSIM=0.7369, RMSE=0.0110, MAE=0.0053
# Epoch 9: Train PSNR=25.51, SSIM=0.8045, RMSE=0.0058, MAE=0.0029 | Valid PSNR=22.14, SSIM=0.7698, RMSE=0.0111, MAE=0.0053
# Epoch 10: Train PSNR=26.13, SSIM=0.8197, RMSE=0.0048, MAE=0.0023 | Valid PSNR=22.25, SSIM=0.7711, RMSE=0.0110, MAE=0.0051
# Epoch 11: Train PSNR=26.27, SSIM=0.8456, RMSE=0.0054, MAE=0.0024 | Valid PSNR=22.20, SSIM=0.8101, RMSE=0.0110, MAE=0.0051
# Epoch 12: Train PSNR=26.08, SSIM=0.8319, RMSE=0.0058, MAE=0.0027 | Valid PSNR=22.12, SSIM=0.7952, RMSE=0.0112, MAE=0.0053
# Epoch 13: Train PSNR=25.84, SSIM=0.8519, RMSE=0.0064, MAE=0.0028 | Valid PSNR=22.14, SSIM=0.8158, RMSE=0.0111, MAE=0.0052
# Epoch 14: Train PSNR=26.28, SSIM=0.8468, RMSE=0.0043, MAE=0.0019 | Valid PSNR=22.17, SSIM=0.8027, RMSE=0.0110, MAE=0.0050
# Epoch 15: Train PSNR=26.01, SSIM=0.8678, RMSE=0.0058, MAE=0.0027 | Valid PSNR=22.14, SSIM=0.8213, RMSE=0.0111, MAE=0.0052
# Epoch 16: Train PSNR=25.83, SSIM=0.8675, RMSE=0.0061, MAE=0.0027 | Valid PSNR=22.14, SSIM=0.8264, RMSE=0.0112, MAE=0.0053
# Epoch 17: Train PSNR=26.12, SSIM=0.8589, RMSE=0.0053, MAE=0.0024 | Valid PSNR=22.23, SSIM=0.8078, RMSE=0.0110, MAE=0.0051
# Epoch 18: Train PSNR=25.64, SSIM=0.8559, RMSE=0.0050, MAE=0.0022 | Valid PSNR=22.28, SSIM=0.8166, RMSE=0.0110, MAE=0.0050
# Epoch 19: Train PSNR=25.80, SSIM=0.8716, RMSE=0.0066, MAE=0.0029 | Valid PSNR=22.21, SSIM=0.8339, RMSE=0.0111, MAE=0.0052
# Epoch 20: Train PSNR=26.20, SSIM=0.8727, RMSE=0.0053, MAE=0.0023 | Valid PSNR=22.27, SSIM=0.8194, RMSE=0.0110, MAE=0.0051
# Epoch 21: Train PSNR=26.38, SSIM=0.8357, RMSE=0.0060, MAE=0.0028 | Valid PSNR=22.23, SSIM=0.7909, RMSE=0.0111, MAE=0.0053
# Epoch 22: Train PSNR=26.16, SSIM=0.8863, RMSE=0.0059, MAE=0.0026 | Valid PSNR=22.16, SSIM=0.8361, RMSE=0.0112, MAE=0.0052
# Epoch 23: Train PSNR=26.12, SSIM=0.8749, RMSE=0.0061, MAE=0.0026 | Valid PSNR=22.15, SSIM=0.8354, RMSE=0.0111, MAE=0.0051
# Epoch 24: Train PSNR=25.47, SSIM=0.8441, RMSE=0.0066, MAE=0.0029 | Valid PSNR=22.24, SSIM=0.8135, RMSE=0.0111, MAE=0.0052
# Epoch 25: Train PSNR=26.73, SSIM=0.8835, RMSE=0.0049, MAE=0.0021 | Valid PSNR=22.28, SSIM=0.8401, RMSE=0.0110, MAE=0.0050
# Epoch 26: Train PSNR=25.59, SSIM=0.8847, RMSE=0.0063, MAE=0.0027 | Valid PSNR=22.21, SSIM=0.8431, RMSE=0.0111, MAE=0.0052
# Epoch 27: Train PSNR=25.71, SSIM=0.8667, RMSE=0.0055, MAE=0.0025 | Valid PSNR=22.14, SSIM=0.8299, RMSE=0.0111, MAE=0.0052
# Epoch 28: Train PSNR=26.81, SSIM=0.8866, RMSE=0.0058, MAE=0.0023 | Valid PSNR=22.27, SSIM=0.8296, RMSE=0.0110, MAE=0.0050
# Epoch 29: Train PSNR=25.51, SSIM=0.8806, RMSE=0.0061, MAE=0.0025 | Valid PSNR=22.25, SSIM=0.8342, RMSE=0.0111, MAE=0.0050
# Epoch 30: Train PSNR=25.58, SSIM=0.8751, RMSE=0.0058, MAE=0.0027 | Valid PSNR=22.10, SSIM=0.8371, RMSE=0.0112, MAE=0.0053
# Epoch 31: Train PSNR=26.76, SSIM=0.8954, RMSE=0.0056, MAE=0.0024 | Valid PSNR=22.17, SSIM=0.8357, RMSE=0.0111, MAE=0.0051
# Epoch 32: Train PSNR=26.72, SSIM=0.8950, RMSE=0.0050, MAE=0.0021 | Valid PSNR=22.22, SSIM=0.8452, RMSE=0.0111, MAE=0.0050
# Epoch 33: Train PSNR=26.75, SSIM=0.8830, RMSE=0.0049, MAE=0.0022 | Valid PSNR=22.21, SSIM=0.8407, RMSE=0.0111, MAE=0.0051
# Epoch 34: Train PSNR=26.22, SSIM=0.8882, RMSE=0.0056, MAE=0.0024 | Valid PSNR=22.19, SSIM=0.8399, RMSE=0.0111, MAE=0.0051
# Epoch 35: Train PSNR=26.02, SSIM=0.8780, RMSE=0.0055, MAE=0.0024 | Valid PSNR=22.26, SSIM=0.8264, RMSE=0.0111, MAE=0.0051
# Epoch 36: Train PSNR=26.45, SSIM=0.8910, RMSE=0.0056, MAE=0.0024 | Valid PSNR=22.26, SSIM=0.8361, RMSE=0.0111, MAE=0.0050
# Epoch 37: Train PSNR=26.10, SSIM=0.8919, RMSE=0.0057, MAE=0.0026 | Valid PSNR=22.11, SSIM=0.8454, RMSE=0.0113, MAE=0.0053
# Epoch 38: Train PSNR=26.28, SSIM=0.8958, RMSE=0.0064, MAE=0.0026 | Valid PSNR=22.23, SSIM=0.8467, RMSE=0.0111, MAE=0.0051
# Epoch 39: Train PSNR=25.38, SSIM=0.8860, RMSE=0.0072, MAE=0.0030 | Valid PSNR=22.11, SSIM=0.8429, RMSE=0.0113, MAE=0.0052
# Epoch 40: Train PSNR=26.35, SSIM=0.8799, RMSE=0.0064, MAE=0.0028 | Valid PSNR=22.15, SSIM=0.8388, RMSE=0.0112, MAE=0.0052
# Epoch 41: Train PSNR=25.72, SSIM=0.8886, RMSE=0.0050, MAE=0.0023 | Valid PSNR=22.22, SSIM=0.8459, RMSE=0.0111, MAE=0.0051
# Epoch 42: Train PSNR=26.33, SSIM=0.8864, RMSE=0.0064, MAE=0.0026 | Valid PSNR=22.24, SSIM=0.8350, RMSE=0.0111, MAE=0.0051
# Epoch 43: Train PSNR=25.46, SSIM=0.8710, RMSE=0.0068, MAE=0.0030 | Valid PSNR=22.18, SSIM=0.8263, RMSE=0.0111, MAE=0.0052
# Epoch 44: Train PSNR=26.40, SSIM=0.8918, RMSE=0.0062, MAE=0.0026 | Valid PSNR=22.13, SSIM=0.8379, RMSE=0.0112, MAE=0.0052
# Epoch 45: Train PSNR=25.77, SSIM=0.8914, RMSE=0.0068, MAE=0.0029 | Valid PSNR=22.10, SSIM=0.8473, RMSE=0.0113, MAE=0.0052
# Epoch 46: Train PSNR=25.62, SSIM=0.8847, RMSE=0.0061, MAE=0.0028 | Valid PSNR=22.07, SSIM=0.8404, RMSE=0.0113, MAE=0.0053
# Epoch 47: Train PSNR=25.13, SSIM=0.8723, RMSE=0.0073, MAE=0.0031 | Valid PSNR=22.11, SSIM=0.8334, RMSE=0.0113, MAE=0.0052
# Epoch 48: Train PSNR=25.34, SSIM=0.8805, RMSE=0.0073, MAE=0.0031 | Valid PSNR=22.15, SSIM=0.8406, RMSE=0.0112, MAE=0.0051
# Epoch 49: Train PSNR=26.00, SSIM=0.8919, RMSE=0.0068, MAE=0.0027 | Valid PSNR=22.12, SSIM=0.8382, RMSE=0.0112, MAE=0.0052
# Epoch 50: Train PSNR=26.76, SSIM=0.8952, RMSE=0.0054, MAE=0.0021 | Valid PSNR=22.24, SSIM=0.8359, RMSE=0.0111, MAE=0.0051
# Epoch 51: Train PSNR=25.69, SSIM=0.8911, RMSE=0.0068, MAE=0.0028 | Valid PSNR=22.18, SSIM=0.8404, RMSE=0.0112, MAE=0.0051
# Epoch 52: Train PSNR=26.03, SSIM=0.8968, RMSE=0.0056, MAE=0.0023 | Valid PSNR=22.25, SSIM=0.8453, RMSE=0.0111, MAE=0.0050
# Epoch 53: Train PSNR=25.59, SSIM=0.8830, RMSE=0.0072, MAE=0.0029 | Valid PSNR=22.08, SSIM=0.8383, RMSE=0.0113, MAE=0.0053
# Epoch 54: Train PSNR=25.86, SSIM=0.8959, RMSE=0.0058, MAE=0.0024 | Valid PSNR=22.15, SSIM=0.8460, RMSE=0.0112, MAE=0.0051
# Epoch 55: Train PSNR=26.05, SSIM=0.8834, RMSE=0.0063, MAE=0.0026 | Valid PSNR=22.16, SSIM=0.8384, RMSE=0.0112, MAE=0.0051
# Epoch 56: Train PSNR=26.92, SSIM=0.8870, RMSE=0.0052, MAE=0.0020 | Valid PSNR=22.19, SSIM=0.8343, RMSE=0.0112, MAE=0.0051
# Epoch 57: Train PSNR=25.99, SSIM=0.8903, RMSE=0.0064, MAE=0.0027 | Valid PSNR=22.18, SSIM=0.8388, RMSE=0.0112, MAE=0.0051
# Epoch 58: Train PSNR=26.14, SSIM=0.8973, RMSE=0.0067, MAE=0.0027 | Valid PSNR=22.21, SSIM=0.8493, RMSE=0.0111, MAE=0.0051
# Epoch 59: Train PSNR=25.78, SSIM=0.8889, RMSE=0.0052, MAE=0.0023 | Valid PSNR=22.21, SSIM=0.8425, RMSE=0.0111, MAE=0.0051
# Epoch 60: Train PSNR=26.10, SSIM=0.8910, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.16, SSIM=0.8427, RMSE=0.0112, MAE=0.0051
# Epoch 61: Train PSNR=26.99, SSIM=0.9052, RMSE=0.0045, MAE=0.0019 | Valid PSNR=22.19, SSIM=0.8460, RMSE=0.0112, MAE=0.0051
# Epoch 62: Train PSNR=27.01, SSIM=0.9030, RMSE=0.0059, MAE=0.0023 | Valid PSNR=22.21, SSIM=0.8453, RMSE=0.0111, MAE=0.0051
# Epoch 63: Train PSNR=26.48, SSIM=0.9020, RMSE=0.0058, MAE=0.0024 | Valid PSNR=22.16, SSIM=0.8498, RMSE=0.0112, MAE=0.0052
# Epoch 64: Train PSNR=25.02, SSIM=0.8828, RMSE=0.0077, MAE=0.0031 | Valid PSNR=22.02, SSIM=0.8463, RMSE=0.0114, MAE=0.0053
# Epoch 65: Train PSNR=27.03, SSIM=0.9026, RMSE=0.0053, MAE=0.0021 | Valid PSNR=22.26, SSIM=0.8468, RMSE=0.0111, MAE=0.0050
# Epoch 66: Train PSNR=26.09, SSIM=0.8999, RMSE=0.0060, MAE=0.0026 | Valid PSNR=22.12, SSIM=0.8478, RMSE=0.0112, MAE=0.0052
# Epoch 67: Train PSNR=26.57, SSIM=0.9027, RMSE=0.0058, MAE=0.0024 | Valid PSNR=22.10, SSIM=0.8488, RMSE=0.0113, MAE=0.0051
# Epoch 68: Train PSNR=26.69, SSIM=0.9029, RMSE=0.0060, MAE=0.0023 | Valid PSNR=22.14, SSIM=0.8520, RMSE=0.0112, MAE=0.0051
# Epoch 69: Train PSNR=26.44, SSIM=0.8980, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.18, SSIM=0.8414, RMSE=0.0112, MAE=0.0052
# Epoch 70: Train PSNR=25.77, SSIM=0.8849, RMSE=0.0055, MAE=0.0024 | Valid PSNR=22.20, SSIM=0.8292, RMSE=0.0112, MAE=0.0052
# Epoch 71: Train PSNR=25.85, SSIM=0.8931, RMSE=0.0068, MAE=0.0028 | Valid PSNR=22.15, SSIM=0.8411, RMSE=0.0112, MAE=0.0052
# Epoch 72: Train PSNR=26.18, SSIM=0.8893, RMSE=0.0062, MAE=0.0025 | Valid PSNR=22.17, SSIM=0.8433, RMSE=0.0111, MAE=0.0051
# Epoch 73: Train PSNR=26.01, SSIM=0.8923, RMSE=0.0056, MAE=0.0025 | Valid PSNR=22.03, SSIM=0.8453, RMSE=0.0114, MAE=0.0053
# Epoch 74: Train PSNR=26.17, SSIM=0.8984, RMSE=0.0057, MAE=0.0022 | Valid PSNR=22.29, SSIM=0.8459, RMSE=0.0110, MAE=0.0050
# Epoch 75: Train PSNR=26.37, SSIM=0.8992, RMSE=0.0059, MAE=0.0024 | Valid PSNR=22.12, SSIM=0.8431, RMSE=0.0113, MAE=0.0052
# Epoch 76: Train PSNR=26.61, SSIM=0.9005, RMSE=0.0062, MAE=0.0024 | Valid PSNR=22.15, SSIM=0.8452, RMSE=0.0112, MAE=0.0051
# Epoch 77: Train PSNR=26.57, SSIM=0.8979, RMSE=0.0062, MAE=0.0025 | Valid PSNR=22.13, SSIM=0.8480, RMSE=0.0113, MAE=0.0051
# Epoch 78: Train PSNR=26.41, SSIM=0.8984, RMSE=0.0054, MAE=0.0023 | Valid PSNR=22.14, SSIM=0.8495, RMSE=0.0112, MAE=0.0051
# Epoch 79: Train PSNR=26.19, SSIM=0.8894, RMSE=0.0052, MAE=0.0022 | Valid PSNR=22.31, SSIM=0.8359, RMSE=0.0110, MAE=0.0050
# Epoch 80: Train PSNR=25.84, SSIM=0.9017, RMSE=0.0060, MAE=0.0025 | Valid PSNR=22.16, SSIM=0.8495, RMSE=0.0112, MAE=0.0051
# Epoch 81: Train PSNR=25.92, SSIM=0.9007, RMSE=0.0052, MAE=0.0022 | Valid PSNR=22.12, SSIM=0.8471, RMSE=0.0113, MAE=0.0052
# Epoch 82: Train PSNR=26.48, SSIM=0.8947, RMSE=0.0060, MAE=0.0023 | Valid PSNR=22.17, SSIM=0.8389, RMSE=0.0112, MAE=0.0051
# Epoch 83: Train PSNR=26.63, SSIM=0.9044, RMSE=0.0052, MAE=0.0021 | Valid PSNR=22.27, SSIM=0.8461, RMSE=0.0111, MAE=0.0050
# Epoch 84: Train PSNR=25.83, SSIM=0.8948, RMSE=0.0067, MAE=0.0028 | Valid PSNR=22.11, SSIM=0.8481, RMSE=0.0113, MAE=0.0052
# Epoch 85: Train PSNR=26.09, SSIM=0.8909, RMSE=0.0062, MAE=0.0026 | Valid PSNR=22.15, SSIM=0.8465, RMSE=0.0112, MAE=0.0052
# Epoch 86: Train PSNR=26.93, SSIM=0.9153, RMSE=0.0045, MAE=0.0017 | Valid PSNR=22.20, SSIM=0.8462, RMSE=0.0112, MAE=0.0051
# Epoch 87: Train PSNR=26.69, SSIM=0.9001, RMSE=0.0061, MAE=0.0024 | Valid PSNR=22.25, SSIM=0.8446, RMSE=0.0111, MAE=0.0051
# Epoch 88: Train PSNR=24.78, SSIM=0.8813, RMSE=0.0080, MAE=0.0033 | Valid PSNR=21.97, SSIM=0.8406, RMSE=0.0115, MAE=0.0053
# Epoch 89: Train PSNR=25.95, SSIM=0.8803, RMSE=0.0063, MAE=0.0027 | Valid PSNR=22.14, SSIM=0.8389, RMSE=0.0113, MAE=0.0052
# Epoch 90: Train PSNR=26.32, SSIM=0.8968, RMSE=0.0059, MAE=0.0023 | Valid PSNR=22.19, SSIM=0.8441, RMSE=0.0112, MAE=0.0051
# Epoch 91: Train PSNR=26.50, SSIM=0.9014, RMSE=0.0053, MAE=0.0021 | Valid PSNR=22.26, SSIM=0.8434, RMSE=0.0111, MAE=0.0050
# Epoch 92: Train PSNR=26.49, SSIM=0.8981, RMSE=0.0048, MAE=0.0020 | Valid PSNR=22.15, SSIM=0.8381, RMSE=0.0112, MAE=0.0051
# Epoch 93: Train PSNR=25.38, SSIM=0.8918, RMSE=0.0072, MAE=0.0032 | Valid PSNR=22.05, SSIM=0.8481, RMSE=0.0114, MAE=0.0052
# Epoch 94: Train PSNR=25.60, SSIM=0.8904, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.18, SSIM=0.8385, RMSE=0.0112, MAE=0.0051
# Epoch 95: Train PSNR=25.33, SSIM=0.8868, RMSE=0.0069, MAE=0.0029 | Valid PSNR=22.16, SSIM=0.8418, RMSE=0.0112, MAE=0.0051
# Epoch 96: Train PSNR=26.37, SSIM=0.9032, RMSE=0.0063, MAE=0.0025 | Valid PSNR=22.17, SSIM=0.8505, RMSE=0.0112, MAE=0.0051
# Epoch 97: Train PSNR=26.08, SSIM=0.8930, RMSE=0.0061, MAE=0.0024 | Valid PSNR=22.21, SSIM=0.8454, RMSE=0.0112, MAE=0.0050
# Epoch 98: Train PSNR=25.73, SSIM=0.8969, RMSE=0.0070, MAE=0.0029 | Valid PSNR=22.03, SSIM=0.8454, RMSE=0.0114, MAE=0.0053
# Epoch 99: Train PSNR=26.55, SSIM=0.9024, RMSE=0.0049, MAE=0.0021 | Valid PSNR=22.23, SSIM=0.8462, RMSE=0.0111, MAE=0.0051
# Epoch 100: Train PSNR=26.74, SSIM=0.9032, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.22, SSIM=0.8462, RMSE=0.0111, MAE=0.0051
# Epoch 101: Train PSNR=26.36, SSIM=0.9053, RMSE=0.0048, MAE=0.0018 | Valid PSNR=22.28, SSIM=0.8426, RMSE=0.0111, MAE=0.0050
# Epoch 102: Train PSNR=26.41, SSIM=0.8987, RMSE=0.0050, MAE=0.0022 | Valid PSNR=22.22, SSIM=0.8456, RMSE=0.0111, MAE=0.0051
# Epoch 103: Train PSNR=25.84, SSIM=0.8975, RMSE=0.0063, MAE=0.0026 | Valid PSNR=22.14, SSIM=0.8494, RMSE=0.0112, MAE=0.0051
# Epoch 104: Train PSNR=26.31, SSIM=0.8987, RMSE=0.0053, MAE=0.0022 | Valid PSNR=22.21, SSIM=0.8455, RMSE=0.0111, MAE=0.0050
# Epoch 105: Train PSNR=26.03, SSIM=0.8993, RMSE=0.0069, MAE=0.0027 | Valid PSNR=22.09, SSIM=0.8454, RMSE=0.0113, MAE=0.0052
# Epoch 106: Train PSNR=26.51, SSIM=0.9063, RMSE=0.0050, MAE=0.0021 | Valid PSNR=22.20, SSIM=0.8491, RMSE=0.0112, MAE=0.0051
# Epoch 107: Train PSNR=27.30, SSIM=0.9130, RMSE=0.0052, MAE=0.0020 | Valid PSNR=22.20, SSIM=0.8488, RMSE=0.0112, MAE=0.0051
# Epoch 108: Train PSNR=26.21, SSIM=0.9086, RMSE=0.0052, MAE=0.0021 | Valid PSNR=22.20, SSIM=0.8499, RMSE=0.0112, MAE=0.0051
# Epoch 109: Train PSNR=26.53, SSIM=0.9011, RMSE=0.0056, MAE=0.0023 | Valid PSNR=22.10, SSIM=0.8470, RMSE=0.0113, MAE=0.0052
# Epoch 110: Train PSNR=27.17, SSIM=0.9150, RMSE=0.0045, MAE=0.0017 | Valid PSNR=22.24, SSIM=0.8498, RMSE=0.0111, MAE=0.0050
# Epoch 111: Train PSNR=26.26, SSIM=0.9032, RMSE=0.0047, MAE=0.0018 | Valid PSNR=22.20, SSIM=0.8453, RMSE=0.0111, MAE=0.0050
# Epoch 112: Train PSNR=25.23, SSIM=0.8911, RMSE=0.0079, MAE=0.0031 | Valid PSNR=21.97, SSIM=0.8481, RMSE=0.0115, MAE=0.0053
# Epoch 113: Train PSNR=26.63, SSIM=0.9027, RMSE=0.0044, MAE=0.0019 | Valid PSNR=22.23, SSIM=0.8488, RMSE=0.0111, MAE=0.0050
# Epoch 114: Train PSNR=26.95, SSIM=0.9091, RMSE=0.0043, MAE=0.0018 | Valid PSNR=22.14, SSIM=0.8475, RMSE=0.0112, MAE=0.0051
# Epoch 115: Train PSNR=24.85, SSIM=0.8803, RMSE=0.0075, MAE=0.0031 | Valid PSNR=22.11, SSIM=0.8370, RMSE=0.0113, MAE=0.0052
# Epoch 116: Train PSNR=25.46, SSIM=0.8907, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.33, SSIM=0.8438, RMSE=0.0110, MAE=0.0050
# Epoch 117: Train PSNR=26.69, SSIM=0.8990, RMSE=0.0056, MAE=0.0023 | Valid PSNR=22.17, SSIM=0.8446, RMSE=0.0112, MAE=0.0051
# Epoch 118: Train PSNR=26.78, SSIM=0.9081, RMSE=0.0050, MAE=0.0021 | Valid PSNR=22.21, SSIM=0.8501, RMSE=0.0112, MAE=0.0051
# Epoch 119: Train PSNR=26.38, SSIM=0.9049, RMSE=0.0055, MAE=0.0021 | Valid PSNR=22.27, SSIM=0.8466, RMSE=0.0111, MAE=0.0050
# Epoch 120: Train PSNR=25.85, SSIM=0.8780, RMSE=0.0065, MAE=0.0028 | Valid PSNR=22.17, SSIM=0.8355, RMSE=0.0112, MAE=0.0051
# Epoch 121: Train PSNR=26.35, SSIM=0.8972, RMSE=0.0066, MAE=0.0025 | Valid PSNR=22.25, SSIM=0.8429, RMSE=0.0111, MAE=0.0051
# Epoch 122: Train PSNR=26.20, SSIM=0.9002, RMSE=0.0061, MAE=0.0026 | Valid PSNR=22.13, SSIM=0.8508, RMSE=0.0112, MAE=0.0051
# Epoch 123: Train PSNR=24.91, SSIM=0.8832, RMSE=0.0075, MAE=0.0032 | Valid PSNR=22.06, SSIM=0.8380, RMSE=0.0114, MAE=0.0053
# Epoch 124: Train PSNR=25.54, SSIM=0.8918, RMSE=0.0057, MAE=0.0026 | Valid PSNR=22.19, SSIM=0.8474, RMSE=0.0112, MAE=0.0051
# Epoch 125: Train PSNR=25.87, SSIM=0.8947, RMSE=0.0066, MAE=0.0027 | Valid PSNR=22.20, SSIM=0.8421, RMSE=0.0112, MAE=0.0051
# Epoch 126: Train PSNR=25.38, SSIM=0.8769, RMSE=0.0072, MAE=0.0031 | Valid PSNR=22.13, SSIM=0.8394, RMSE=0.0113, MAE=0.0052
# Epoch 127: Train PSNR=26.15, SSIM=0.9030, RMSE=0.0052, MAE=0.0023 | Valid PSNR=22.23, SSIM=0.8476, RMSE=0.0111, MAE=0.0051
# Epoch 128: Train PSNR=25.86, SSIM=0.8973, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.19, SSIM=0.8511, RMSE=0.0112, MAE=0.0051
# Epoch 129: Train PSNR=26.13, SSIM=0.9064, RMSE=0.0057, MAE=0.0023 | Valid PSNR=22.20, SSIM=0.8499, RMSE=0.0112, MAE=0.0051
# Epoch 130: Train PSNR=25.93, SSIM=0.8983, RMSE=0.0065, MAE=0.0026 | Valid PSNR=22.15, SSIM=0.8470, RMSE=0.0112, MAE=0.0051
# Epoch 131: Train PSNR=26.02, SSIM=0.8926, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.13, SSIM=0.8342, RMSE=0.0113, MAE=0.0052
# Epoch 132: Train PSNR=26.07, SSIM=0.9030, RMSE=0.0067, MAE=0.0027 | Valid PSNR=22.12, SSIM=0.8519, RMSE=0.0113, MAE=0.0052
# Epoch 133: Train PSNR=25.69, SSIM=0.8925, RMSE=0.0069, MAE=0.0029 | Valid PSNR=22.07, SSIM=0.8499, RMSE=0.0113, MAE=0.0052
# Epoch 134: Train PSNR=25.32, SSIM=0.8962, RMSE=0.0056, MAE=0.0025 | Valid PSNR=22.19, SSIM=0.8507, RMSE=0.0112, MAE=0.0051
# Epoch 135: Train PSNR=26.16, SSIM=0.8987, RMSE=0.0059, MAE=0.0025 | Valid PSNR=22.24, SSIM=0.8486, RMSE=0.0111, MAE=0.0050
# Epoch 136: Train PSNR=26.40, SSIM=0.9067, RMSE=0.0054, MAE=0.0022 | Valid PSNR=22.14, SSIM=0.8497, RMSE=0.0112, MAE=0.0051
# Epoch 137: Train PSNR=26.74, SSIM=0.9044, RMSE=0.0062, MAE=0.0024 | Valid PSNR=22.16, SSIM=0.8436, RMSE=0.0112, MAE=0.0052
# Epoch 138: Train PSNR=26.30, SSIM=0.9044, RMSE=0.0058, MAE=0.0024 | Valid PSNR=22.12, SSIM=0.8508, RMSE=0.0113, MAE=0.0051
# Epoch 139: Train PSNR=25.92, SSIM=0.8964, RMSE=0.0057, MAE=0.0024 | Valid PSNR=22.14, SSIM=0.8399, RMSE=0.0112, MAE=0.0051
# Epoch 140: Train PSNR=26.51, SSIM=0.9017, RMSE=0.0062, MAE=0.0024 | Valid PSNR=22.18, SSIM=0.8472, RMSE=0.0112, MAE=0.0051
# Epoch 141: Train PSNR=25.71, SSIM=0.8962, RMSE=0.0066, MAE=0.0026 | Valid PSNR=22.20, SSIM=0.8466, RMSE=0.0112, MAE=0.0050
# Epoch 142: Train PSNR=25.73, SSIM=0.9029, RMSE=0.0050, MAE=0.0021 | Valid PSNR=22.14, SSIM=0.8499, RMSE=0.0112, MAE=0.0051
# Epoch 143: Train PSNR=27.04, SSIM=0.9105, RMSE=0.0054, MAE=0.0021 | Valid PSNR=22.19, SSIM=0.8488, RMSE=0.0112, MAE=0.0051
# Epoch 144: Train PSNR=26.50, SSIM=0.9143, RMSE=0.0044, MAE=0.0019 | Valid PSNR=22.19, SSIM=0.8502, RMSE=0.0112, MAE=0.0051
# Epoch 145: Train PSNR=26.78, SSIM=0.9077, RMSE=0.0042, MAE=0.0017 | Valid PSNR=22.31, SSIM=0.8447, RMSE=0.0110, MAE=0.0050
# Epoch 146: Train PSNR=25.79, SSIM=0.8970, RMSE=0.0065, MAE=0.0027 | Valid PSNR=22.10, SSIM=0.8437, RMSE=0.0113, MAE=0.0052
# Epoch 147: Train PSNR=26.21, SSIM=0.9105, RMSE=0.0053, MAE=0.0022 | Valid PSNR=22.15, SSIM=0.8542, RMSE=0.0112, MAE=0.0052
# Epoch 148: Train PSNR=25.53, SSIM=0.8949, RMSE=0.0056, MAE=0.0025 | Valid PSNR=22.07, SSIM=0.8492, RMSE=0.0113, MAE=0.0052
# Epoch 149: Train PSNR=26.43, SSIM=0.9023, RMSE=0.0056, MAE=0.0023 | Valid PSNR=22.31, SSIM=0.8471, RMSE=0.0110, MAE=0.0050
# Epoch 150: Train PSNR=26.07, SSIM=0.8974, RMSE=0.0057, MAE=0.0023 | Valid PSNR=22.28, SSIM=0.8454, RMSE=0.0111, MAE=0.0050
# Epoch 151: Train PSNR=26.21, SSIM=0.9040, RMSE=0.0063, MAE=0.0024 | Valid PSNR=22.21, SSIM=0.8517, RMSE=0.0112, MAE=0.0051
# Epoch 152: Train PSNR=26.88, SSIM=0.9090, RMSE=0.0052, MAE=0.0020 | Valid PSNR=22.25, SSIM=0.8535, RMSE=0.0111, MAE=0.0050
# Epoch 153: Train PSNR=26.40, SSIM=0.9077, RMSE=0.0055, MAE=0.0023 | Valid PSNR=22.16, SSIM=0.8524, RMSE=0.0112, MAE=0.0051
# Epoch 154: Train PSNR=26.64, SSIM=0.9137, RMSE=0.0052, MAE=0.0022 | Valid PSNR=22.11, SSIM=0.8510, RMSE=0.0113, MAE=0.0052
# Epoch 155: Train PSNR=26.66, SSIM=0.9107, RMSE=0.0050, MAE=0.0020 | Valid PSNR=22.25, SSIM=0.8497, RMSE=0.0111, MAE=0.0050
# Epoch 156: Train PSNR=25.52, SSIM=0.8999, RMSE=0.0057, MAE=0.0026 | Valid PSNR=22.09, SSIM=0.8504, RMSE=0.0113, MAE=0.0052
# Epoch 157: Train PSNR=26.27, SSIM=0.9055, RMSE=0.0055, MAE=0.0022 | Valid PSNR=22.24, SSIM=0.8460, RMSE=0.0111, MAE=0.0050
# Epoch 158: Train PSNR=26.18, SSIM=0.8984, RMSE=0.0057, MAE=0.0023 | Valid PSNR=22.19, SSIM=0.8458, RMSE=0.0112, MAE=0.0051
# Epoch 159: Train PSNR=26.26, SSIM=0.9041, RMSE=0.0053, MAE=0.0023 | Valid PSNR=22.14, SSIM=0.8486, RMSE=0.0112, MAE=0.0051
# Epoch 160: Train PSNR=25.04, SSIM=0.8860, RMSE=0.0077, MAE=0.0031 | Valid PSNR=22.16, SSIM=0.8449, RMSE=0.0112, MAE=0.0051
# Epoch 161: Train PSNR=25.88, SSIM=0.9033, RMSE=0.0062, MAE=0.0026 | Valid PSNR=22.03, SSIM=0.8502, RMSE=0.0114, MAE=0.0052
# Epoch 162: Train PSNR=26.33, SSIM=0.9015, RMSE=0.0051, MAE=0.0021 | Valid PSNR=22.25, SSIM=0.8465, RMSE=0.0111, MAE=0.0050
# Epoch 163: Train PSNR=25.97, SSIM=0.8978, RMSE=0.0058, MAE=0.0023 | Valid PSNR=22.24, SSIM=0.8507, RMSE=0.0111, MAE=0.0050
# Epoch 164: Train PSNR=25.82, SSIM=0.9007, RMSE=0.0069, MAE=0.0027 | Valid PSNR=22.20, SSIM=0.8485, RMSE=0.0111, MAE=0.0051
# Epoch 165: Train PSNR=25.36, SSIM=0.8959, RMSE=0.0069, MAE=0.0028 | Valid PSNR=22.12, SSIM=0.8466, RMSE=0.0113, MAE=0.0052
# Epoch 166: Train PSNR=25.92, SSIM=0.8985, RMSE=0.0069, MAE=0.0027 | Valid PSNR=22.17, SSIM=0.8458, RMSE=0.0112, MAE=0.0051
# Epoch 167: Train PSNR=26.57, SSIM=0.9071, RMSE=0.0062, MAE=0.0025 | Valid PSNR=22.15, SSIM=0.8528, RMSE=0.0112, MAE=0.0051
# Epoch 168: Train PSNR=26.60, SSIM=0.9027, RMSE=0.0059, MAE=0.0024 | Valid PSNR=22.16, SSIM=0.8463, RMSE=0.0112, MAE=0.0051
# Epoch 169: Train PSNR=25.20, SSIM=0.8924, RMSE=0.0074, MAE=0.0030 | Valid PSNR=22.09, SSIM=0.8441, RMSE=0.0113, MAE=0.0052
# Epoch 170: Train PSNR=26.04, SSIM=0.9129, RMSE=0.0048, MAE=0.0020 | Valid PSNR=22.21, SSIM=0.8498, RMSE=0.0111, MAE=0.0051
# Epoch 171: Train PSNR=26.08, SSIM=0.9009, RMSE=0.0057, MAE=0.0025 | Valid PSNR=22.14, SSIM=0.8505, RMSE=0.0113, MAE=0.0052
# Epoch 172: Train PSNR=26.01, SSIM=0.9000, RMSE=0.0065, MAE=0.0027 | Valid PSNR=22.12, SSIM=0.8481, RMSE=0.0113, MAE=0.0051
# Epoch 173: Train PSNR=26.36, SSIM=0.9095, RMSE=0.0059, MAE=0.0024 | Valid PSNR=22.16, SSIM=0.8530, RMSE=0.0112, MAE=0.0051
# Epoch 174: Train PSNR=25.32, SSIM=0.8921, RMSE=0.0073, MAE=0.0029 | Valid PSNR=22.07, SSIM=0.8484, RMSE=0.0113, MAE=0.0051
# Epoch 175: Train PSNR=25.29, SSIM=0.8956, RMSE=0.0064, MAE=0.0028 | Valid PSNR=22.08, SSIM=0.8495, RMSE=0.0113, MAE=0.0052
# Epoch 176: Train PSNR=26.76, SSIM=0.9045, RMSE=0.0062, MAE=0.0024 | Valid PSNR=22.11, SSIM=0.8478, RMSE=0.0113, MAE=0.0052
# Epoch 177: Train PSNR=24.68, SSIM=0.8821, RMSE=0.0077, MAE=0.0032 | Valid PSNR=22.02, SSIM=0.8390, RMSE=0.0114, MAE=0.0053
# Epoch 178: Train PSNR=27.58, SSIM=0.9150, RMSE=0.0052, MAE=0.0019 | Valid PSNR=22.24, SSIM=0.8465, RMSE=0.0111, MAE=0.0051
# Epoch 179: Train PSNR=25.91, SSIM=0.8936, RMSE=0.0067, MAE=0.0028 | Valid PSNR=22.16, SSIM=0.8484, RMSE=0.0112, MAE=0.0051
# Epoch 180: Train PSNR=26.24, SSIM=0.9007, RMSE=0.0057, MAE=0.0023 | Valid PSNR=22.11, SSIM=0.8437, RMSE=0.0113, MAE=0.0051
# Epoch 181: Train PSNR=26.10, SSIM=0.9031, RMSE=0.0062, MAE=0.0025 | Valid PSNR=22.17, SSIM=0.8510, RMSE=0.0112, MAE=0.0051
# Epoch 182: Train PSNR=26.10, SSIM=0.9044, RMSE=0.0061, MAE=0.0024 | Valid PSNR=22.18, SSIM=0.8532, RMSE=0.0112, MAE=0.0051
# Epoch 183: Train PSNR=26.15, SSIM=0.8990, RMSE=0.0053, MAE=0.0022 | Valid PSNR=22.19, SSIM=0.8459, RMSE=0.0112, MAE=0.0051
# Epoch 184: Train PSNR=26.88, SSIM=0.9074, RMSE=0.0053, MAE=0.0021 | Valid PSNR=22.14, SSIM=0.8466, RMSE=0.0113, MAE=0.0052
# Epoch 185: Train PSNR=26.70, SSIM=0.9078, RMSE=0.0059, MAE=0.0026 | Valid PSNR=22.18, SSIM=0.8517, RMSE=0.0112, MAE=0.0051
# Epoch 186: Train PSNR=25.18, SSIM=0.8942, RMSE=0.0073, MAE=0.0030 | Valid PSNR=22.02, SSIM=0.8520, RMSE=0.0114, MAE=0.0052
# Epoch 187: Train PSNR=26.49, SSIM=0.9055, RMSE=0.0061, MAE=0.0025 | Valid PSNR=22.10, SSIM=0.8472, RMSE=0.0113, MAE=0.0052
# Epoch 188: Train PSNR=25.45, SSIM=0.9011, RMSE=0.0063, MAE=0.0026 | Valid PSNR=22.12, SSIM=0.8506, RMSE=0.0112, MAE=0.0052
# Epoch 189: Train PSNR=26.32, SSIM=0.8926, RMSE=0.0049, MAE=0.0020 | Valid PSNR=22.11, SSIM=0.8408, RMSE=0.0113, MAE=0.0051
# Epoch 190: Train PSNR=26.76, SSIM=0.9077, RMSE=0.0053, MAE=0.0021 | Valid PSNR=22.21, SSIM=0.8456, RMSE=0.0112, MAE=0.0051
# Epoch 191: Train PSNR=25.52, SSIM=0.8981, RMSE=0.0062, MAE=0.0025 | Valid PSNR=22.15, SSIM=0.8488, RMSE=0.0112, MAE=0.0051
# Epoch 192: Train PSNR=24.80, SSIM=0.8766, RMSE=0.0079, MAE=0.0034 | Valid PSNR=22.04, SSIM=0.8393, RMSE=0.0114, MAE=0.0053
# Epoch 193: Train PSNR=26.15, SSIM=0.9121, RMSE=0.0048, MAE=0.0020 | Valid PSNR=22.09, SSIM=0.8535, RMSE=0.0113, MAE=0.0051
# Epoch 194: Train PSNR=26.11, SSIM=0.8989, RMSE=0.0055, MAE=0.0024 | Valid PSNR=22.18, SSIM=0.8416, RMSE=0.0112, MAE=0.0051
# Epoch 195: Train PSNR=27.03, SSIM=0.9015, RMSE=0.0048, MAE=0.0020 | Valid PSNR=22.10, SSIM=0.8458, RMSE=0.0113, MAE=0.0052
# Epoch 196: Train PSNR=25.37, SSIM=0.8968, RMSE=0.0074, MAE=0.0029 | Valid PSNR=22.12, SSIM=0.8493, RMSE=0.0113, MAE=0.0052
# Epoch 197: Train PSNR=25.17, SSIM=0.8945, RMSE=0.0070, MAE=0.0030 | Valid PSNR=22.08, SSIM=0.8504, RMSE=0.0113, MAE=0.0052
# Epoch 198: Train PSNR=25.68, SSIM=0.8946, RMSE=0.0070, MAE=0.0027 | Valid PSNR=22.15, SSIM=0.8455, RMSE=0.0113, MAE=0.0051
# Epoch 199: Train PSNR=25.34, SSIM=0.8953, RMSE=0.0070, MAE=0.0029 | Valid PSNR=22.10, SSIM=0.8506, RMSE=0.0113, MAE=0.0052
# Epoch 200: Train PSNR=26.44, SSIM=0.9095, RMSE=0.0050, MAE=0.0020 | Valid PSNR=22.19, SSIM=0.8487, RMSE=0.0112, MAE=0.0051

# %% [markdown]
# # 评估

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

torch.save(G.state_dict(), "G_ESM.pth")
print("✅ 模型保存至 G_ESM.pth")

# === 1. 加载测试集 ===
test_set = WeatherDataset(
    "tm/LR_data_test_40.npy", "tm/HR_data_test_40.npy",
    "tm/mean_40.npy", "tm/std_40.npy"
)
test_loader = DataLoader(test_set, batch_size=8, shuffle=False)

# === 2. 在测试集上评估模型 ===
G = SRResNetGenerator().to(device)
G.load_state_dict(torch.load("G_ESM.pth"))
G.eval()
test_psnrs, test_ssims, test_rmses, test_maes = [], [], [], []
images_to_show = []  # 原图、真实图、预测图（反归一化后）

# 反归一化函数
mean = np.load("tm/mean_40.npy")
std = np.load("tm/std_40.npy")
def denormalize(tensor):
    return tensor * torch.tensor(std).to(tensor.device) + torch.tensor(mean).to(tensor.device)

with torch.no_grad():
    for test_lr, test_hr in test_loader:
        test_lr, test_hr = test_lr.to(device), test_hr.to(device)
        pred_test = G(test_lr)
        pred_test = F.interpolate(pred_test, size=test_hr.shape[-2:], mode="bilinear", align_corners=False)

        # 计算指标（归一化下）
        pred_mm = minmax_scale(pred_test)
        hr_mm = minmax_scale(test_hr)
        psnr, ssim = compute_psnr_ssim(pred_test, test_hr)
        rmse = compute_rmse(pred_mm, hr_mm)
        mae = compute_mae(pred_mm, hr_mm)
        test_psnrs.append(psnr)
        test_ssims.append(ssim)
        test_rmses.append(rmse.cpu().item())
        test_maes.append(mae.cpu().item())

        # 可视化：选取前1张图，反归一化
        for i in range(1):
            lr_img = F.interpolate(test_lr[i:i+1], size=(64, 64), mode="bilinear", align_corners=False)
            images_to_show.append((
                denormalize(lr_img[0].cpu()),
                denormalize(test_hr[i].cpu()),
                denormalize(pred_test[i].cpu())
            ))

# === 3. 打印测试集平均指标 ===
print(f"Test Set Evaluation for ESM:")
print(f"PSNR: {np.mean(test_psnrs):.2f}")
print(f"SSIM: {np.mean(test_ssims):.4f}")
print(f"RMSE: {np.mean(test_rmses):.4f}")
print(f"MAE: {np.mean(test_maes):.4f}")
# Out:
# ✅ 模型保存至 G_ESM.pth
# /var/folders/4p/p5h6h2t5317gljf_p2xg65wc0000gn/T/ipykernel_1026/1410872527.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G.load_state_dict(torch.load("G_ESM.pth"))
# Test Set Evaluation for ESM:
# PSNR: 23.41
# SSIM: 0.8417
# RMSE: 0.0087
# MAE: 0.0041

# %%
import matplotlib.pyplot as plt

# ========== 设置模型为评估模式 ==========
G.eval()
with torch.no_grad():
    # 获取测试集的第一个 batch
    test_lr, test_hr = next(iter(train_loader))
    test_lr, test_hr = test_lr.to(device), test_hr.to(device)

    # 生成模型输出
    generated_output = G(test_lr)
    generated_output = F.interpolate(generated_output, size=test_hr.shape[-2:], mode="bilinear", align_corners=False)

    # 反归一化
    mean = torch.tensor(np.load("tm/mean_40.npy"), dtype=torch.float32).view(2, 1, 1).to(device)
    std = torch.tensor(np.load("tm/std_40.npy"), dtype=torch.float32).view(2, 1, 1).to(device)

    def denormalize(tensor):
        return tensor * std + mean

    test_lr_denorm = F.interpolate(test_lr, size=(64, 64), mode="bilinear", align_corners=False)
    lr_img = denormalize(test_lr_denorm[0]).cpu().numpy().transpose(1, 2, 0)
    hr_img = denormalize(test_hr[0]).cpu().numpy().transpose(1, 2, 0)
    pred_img = denormalize(generated_output[0]).cpu().numpy().transpose(1, 2, 0)

    abs_error = np.abs(pred_img - hr_img)

    # ========== 可视化图像 ==========
    fig, axs = plt.subplots(1, 4, figsize=(20, 5))

    axs[0].imshow(lr_img[:, :, 0], cmap='gray')  # 可改为取其他通道或显示 RGB
    axs[0].set_title("Upsampled LR")
    axs[0].axis("off")

    axs[1].imshow(hr_img[:, :, 0], cmap='gray')
    axs[1].set_title("Ground Truth HR")
    axs[1].axis("off")

    axs[2].imshow(pred_img[:, :, 0], cmap='gray')
    axs[2].set_title("Predicted Output")
    axs[2].axis("off")

    axs[3].imshow(abs_error[:, :, 0], cmap='inferno')
    axs[3].set_title("Absolute Error")
    axs[3].axis("off")

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, len(train_psnrs)+1))

# === PSNR ===
plt.figure(figsize=(10, 4))
plt.plot(epochs, train_psnrs, label="Train PSNR")
plt.plot(epochs, val_psnrs, label="Valid PSNR")
plt.xlabel("Epoch")
plt.ylabel("PSNR")
plt.title("PSNR over Epochs")
plt.legend()
plt.grid(True)
plt.show()
# === SSIM ===
plt.figure(figsize=(10, 4))
plt.plot(epochs, train_ssims, label="Train SSIM")
plt.plot(epochs, val_ssims, label="Valid SSIM")
plt.xlabel("Epoch")
plt.ylabel("SSIM")
plt.title("SSIM over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

# 将数组保存为 .npy 文件
np.save("2_ssim_train.npy", train_ssims)
np.save("2_psnr_train.npy", train_psnrs)
np.save("2_ssim_valid.npy", val_ssims)
np.save("2_psnr_valid.npy", val_psnrs)

print("✅ 已保存为 2_ssim_train.npy, 2_psnr_train.npy, 2_ssim_valid.npy, 2_psnr_valid.npy")
# Out:
# ✅ 已保存为 2_ssim_train.npy, 2_psnr_train.npy, 2_ssim_valid.npy, 2_psnr_valid.npy

# %%
# 确保每个 tensor 都通过 .detach() 断开计算图，之后转移到 CPU 并转换为 NumPy 数组
train_maes_cpu = [mae.detach().cpu().numpy() for mae in train_maes]
train_rmses_cpu = [rmse.detach().cpu().numpy() for rmse in train_rmses]

# 保存为 .npy 文件
np.save("2_mae_train.npy", train_maes_cpu)
np.save("2_rmes_train.npy", train_rmses_cpu)

# %%
# 确保每个 tensor 都通过 .detach() 断开计算图，之后转移到 CPU 并转换为 NumPy 数组
valid_maes_cpu = [mae.detach().cpu().numpy() for mae in val_maes]
valid_rmses_cpu = [rmse.detach().cpu().numpy() for rmse in val_rmses]

# 保存为 .npy 文件
np.save("2_mae_valid.npy", valid_maes_cpu)
np.save("2_rmes_valid.npy", valid_rmses_cpu)

# %%
import numpy as np
import pandas as pd

# .npy 文件的列表
files = [
    "2_mae_train.npy", "2_mae_valid.npy", 
    "2_psnr_train.npy", "2_psnr_valid.npy",
    "2_rmes_train.npy", "2_rmes_valid.npy",
    "2_ssim_train.npy", "2_ssim_valid.npy"
]

# 创建一个字典来存储数据
data_dict = {}

# 加载每个 .npy 文件并存入字典
for file in files:
    data_dict[file] = np.load(file)

# 将字典转换为 pandas DataFrame
df = pd.DataFrame(data_dict)

# 将 DataFrame 保存为 CSV 文件
df.to_csv("融合_data.csv", index=False)
